# %% [markdown]
# # Train YOLOv9 on RoboFlow Dataset

# %% [markdown]
# ## Setup & Clone

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (216/216), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 325 (delta 158), reused 155 (delta 155), pack-reused 109
# Receiving objects: 100% (325/325), 2.23 MiB | 4.06 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.8 MB/s eta 0:00:00

# %%
# !pip install roboflow -q

from roboflow import Roboflow
rf = Roboflow(api_key="JfWvwrqKJO7Axqb2NQpH")
project = rf.workspace("large-benchmark-datasets").project("logistics-sz9jr")
version = project.version(2)
dataset = version.download("yolov9")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.3 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Logistics-2 to yolov9:: 100%|██████████| 4973094/4973094 [03:03<00:00, 27065.14it/s]
# Extracting Dataset Version Zip to Logistics-2 in yolov9:: 100%|██████████| 189460/189460 [00:50<00:00, 3726.84it/s]

# %% [markdown]
# ### Downloading Weights...

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402448
# drwxr-xr-x 2 root root      4096 May 13 11:39 .
# drwxr-xr-x 1 root root      4096 May 13 11:39 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %% [markdown]
# ## Train Custom Model

# %%
# %cd {HOME}/yolov9

# !python train.py \
--batch 16 --epochs 30 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2024-05-13 11:39:41.644184: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-13 11:39:41.644242: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-13 11:39:41.779665: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-13 11:39:44.061085: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=/content/weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=/content/yolov9/Logistics-2/data.yaml, hyp=hyp.scratch-high.yaml, epochs=30, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 31.8MB/s]
# Overriding model.yaml nc=80 with nc=20
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5506060  models.yolo.DDetect                     [20, [256, 512, 512]]
# gelan-c summary: 621 layers, 25452492 parameters, 25452476 gradients, 103.2 GFLOPs
#
# Transferred 931/937 items from /content/weights/gelan-c.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# train: Scanning /content/yolov9/Logistics-2/train/labels... 66211 images, 0 backgrounds, 0 corrupt: 100% 66211/66211 [01:47<00:00, 616.13it/s]
# train: WARNING ⚠️ /content/yolov9/Logistics-2/train/images/-101_jpg.rf.0a42a0ee5ce21c367a20f6f839c48830.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/yolov9/Logistics-2/train/images/-108_jpg.rf.e1955a8660a637ecff5c2885611f1562.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /content/yolov9/Logistics-2/train/images/-126_jpg.rf.b80666265cd5b21a9deff4fc0b30f250.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /content/yolov9/Logistics-2/train/images/06726_jpg.rf.ece9755d68aedbb342db30d93db62227.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/yolov9/Logistics-2/train/images/1-123002001-OCR-LB-C02_jpg.rf.d0b5a4eab8ef806a389df2b1a193d539.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/yolov9/Logistics-2/train/images/1-123152001-OCR-RF-D01_jpg.rf.2e6b399bd07336723048627e5129d2f5.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/yolov9/Logistics-2/train/images/4_z8126b7d060d92d74599e0618_f109cae5016f2275e_d20170225_m202342_c001_v0001038_t0018_png_jpg.rf.dc7ec7eea266d2b61632aca14149759f.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /content/yolov9/Logistics-2/train/images/4_z8126b7d060d92d74599e0618_f109cae5016f22c00_d20170225_m202920_c001_v0001038_t0018_png_jpg.rf.cd0e3b3f490090d1eb9452f5425c282c.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /content/yolov9/Logistics-2/train/images/4_z8126b7d060d92d74599e0618_f110e5e48fac43e95_d20170301_m025708_c001_v0001036_t0016_png_jpg.rf.201e06eca644825e945b30c2aac5a79e.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/yolov9/Logistics-2/train/images/4_z8126b7d060d92d74599e0618_f113b6d39c5da0427_d20170226_m001314_c001_v0001036_t0059_png_jpg.rf.cf5b239fd94bfcd9267fbf1facf9eeab.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/yolov9/Logistics-2/train/images/image_from_china-254-_jpg.rf.c09f0ce70285f6d4ed438ca922083ce3.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/yolov9/Logistics-2/train/images/img_0631_jpg.rf.ae1e87a4ab0a71f63e9853a8e60fc24a.jpg: 1 duplicate labels removed
# train: New cache created: /content/yolov9/Logistics-2/train/labels.cache
# val: Scanning /content/yolov9/Logistics-2/valid/labels... 18988 images, 0 backgrounds, 0 corrupt: 100% 18988/18988 [00:28<00:00, 661.09it/s]
# val: WARNING ⚠️ /content/yolov9/Logistics-2/valid/images/-Docker-1-Do_jpg.rf.5c00af35cf477fec60189674679ea214.jpg: 2 duplicate labels removed
# val: New cache created: /content/yolov9/Logistics-2/valid/labels.cache
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 30 epochs...
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        0/29        14G      1.423      3.649      1.536        152        640:   7% 295/4139 [04:47<1:02:28,  1.03it/s]
# Traceback (most recent call last):
#   File "/content/yolov9/train.py", line 634, in <module>
#     main(opt)
#   File "/content/yolov9/train.py", line 528, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "/content/yolov9/train.py", line 321, in train
#     ema.update(model)
#   File "/content/yolov9/utils/torch_utils.py", line -1, in update
# KeyboardInterrupt
